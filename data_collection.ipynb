# %%
import requests
import pandas as pd

url = "https://archive-api.open-meteo.com/v1/archive"

params = {
    "latitude": 40.71,
    "longitude": -74.00,
    "start_date": "2026-08-01",
    "end_date": "2026-08-31",
    "hourly": "temperature_2m,relative_humidity_2m,precipitation,wind_speed_10m",
    "timezone": "America/New_York"
}

response = requests.get(url, params=params)
data = response.json()

# Convert to DataFrame
weather_df = pd.DataFrame(data["hourly"])
weather_df["time"] = pd.to_datetime(weather_df["time"])

print(weather_df.head())
weather_df.to_csv("nyc_weather.csv", index=False)
# Out:
#                  time  temperature_2m  relative_humidity_2m  precipitation  \
# 0 2026-08-01 00:00:00            23.3                    84            0.0
# 1 2026-08-01 01:00:00            22.7                    85            0.0
# 2 2026-08-01 02:00:00            22.1                    89            0.0
# 3 2026-08-01 03:00:00            21.9                    91            0.0
# 4 2026-08-01 04:00:00            21.7                    93            0.0
#
#    wind_speed_10m
# 0             6.2
# 1             4.6
# 2             6.3
# 3             7.3
# 4             7.0

# %%
import requests
import pandas as pd

url = "https://gbfs.citibikenyc.com/gbfs/en/station_information.json"
response = requests.get(url)
data = response.json()

stations = pd.DataFrame(data["data"]["stations"])
stations.to_csv("station_information.csv", index=False)

print(stations.head())
# Out:
#                              station_id                       name short_name  \
# 0  ba33c334-e17d-4478-ae3c-9c2f4dbfbb51             51 Ave & 61 St    5923.02
# 1  06439006-11b6-44f0-8545-c9d39035f32a       Vesey St & Church St    5216.06
# 2  525535e3-dde3-47b4-9c2e-0174eaa4f2bb         61 St & Borden Ave    5611.04
# 3                   1986707977001495180             21 St & 20 Ave    7363.03
# 4                   1795146692060860976  Longfellow Ave & Aldus St    7983.02
#
#          lon        lat region_id  capacity  \
# 0 -73.903870  40.735680        71         0
# 1 -74.010472  40.712220        71        78
# 2 -73.904170  40.725580        71         0
# 3 -73.912731  40.783936        71        19
# 4 -73.887629  40.823194        71        24
#
#                                          rental_uris     rental_methods  \
# 0  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 1  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 2  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 3  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
# 4  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  [KEY, CREDITCARD]
#
#    has_kiosk station_type                           external_id  \
# 0       True      classic  ba33c334-e17d-4478-ae3c-9c2f4dbfbb51
# 1       True      classic  06439006-11b6-44f0-8545-c9d39035f32a
# 2       True      classic  525535e3-dde3-47b4-9c2e-0174eaa4f2bb
# 3       True      classic                   1986707977001495180
# 4       True      classic                   1795146692060860976
#
#    electric_bike_surcharge_waiver eightd_station_services  \
# 0                           False                      []
# 1                           False                      []
# 2                           False                      []
# 3                           False                      []
# 4                           False                      []
#
#    eightd_has_key_dispenser
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False

# %%
# loading all the three datasets

citi_1=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_1.csv")
citi_2=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_2.csv")
citi_3=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_3.csv")

station=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\station_information.csv")
weather=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\nyc_weather.csv")
# Out:
# C:\Users\vaish\AppData\Local\Temp\ipykernel_22916\4292091360.py:3: DtypeWarning: Columns (0: end_station_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_1=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_1.csv")
# C:\Users\vaish\AppData\Local\Temp\ipykernel_22916\4292091360.py:4: DtypeWarning: Columns (0: end_station_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_2=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_2.csv")
# C:\Users\vaish\AppData\Local\Temp\ipykernel_22916\4292091360.py:5: DtypeWarning: Columns (0: end_station_id) have mixed types. Specify dtype option on import or set low_memory=False.
#   citi_3=pd.read_csv("C:\\Users\\vaish\\OneDrive\\Documents\\DATA SCIENCE COURSE\\Projects\\CitiBike_Project\\data\\raw_dataset\\202608-citibike-tripdata_3.csv")

# %%
# column names

print(citi_1.columns)
print(citi_2.columns)
print(citi_3.columns)
print(station.columns)
print(weather.columns)
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str')
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str')
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='str')
# Index(['station_id', 'name', 'short_name', 'lon', 'lat', 'region_id',
#        'capacity', 'rental_uris', 'rental_methods', 'has_kiosk',
#        'station_type', 'external_id', 'electric_bike_surcharge_waiver',
#        'eightd_station_services', 'eightd_has_key_dispenser'],
#       dtype='str')
# Index(['time', 'temperature_2m', 'relative_humidity_2m', 'precipitation',
#        'wind_speed_10m'],
#       dtype='str')

# %%
print(citi_1.shape)
print(citi_2.shape)
print(citi_3.shape)
print(station.shape)
print(weather.shape)
# Out:
# (1000000, 13)
# (1000000, 13)
# (1000000, 13)
# (2520, 15)
# (744, 5)

# %%
print(citi_1.head())
print(citi_2.head())
print(citi_3.head())
print(station.head())
print(weather.head())
# Out:
#             ride_id  rideable_type               started_at  \
# 0  E4A8132DACF670C3  electric_bike  2026-08-10 14:31:22.100
# 1  8382768C05C30BB4  electric_bike  2026-08-10 08:04:28.348
# 2  3A1C43832BBE4FCD   classic_bike  2026-08-08 19:36:32.350
# 3  5C9BC6DFC4DEA183  electric_bike  2026-08-05 14:34:27.749
# 4  355579CC64D1BE20  electric_bike  2026-08-01 14:16:44.531
#
#                   ended_at         start_station_name start_station_id  \
# 0  2026-08-10 14:37:37.034            E 33 St & 5 Ave          6322.01
# 1  2026-08-10 08:33:27.680    Emerson Pl & Myrtle Ave          4683.02
# 2  2026-08-08 19:43:47.890         Broadway & E 19 St          5980.11
# 3  2026-08-05 14:46:23.526  Sterling Pl & Bedford Ave          3993.03
# 4  2026-08-01 14:29:39.539  Sterling Pl & Bedford Ave          3993.03
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0                W 24 St & 7 Ave        6257.03  40.747659 -73.984907
# 1                W 24 St & 7 Ave        6257.03  40.693631 -73.962236
# 2                W 24 St & 7 Ave        6257.03  40.738290 -73.990060
# 3  Cumberland St & Lafayette Ave        4428.02  40.672695 -73.954131
# 4  Cumberland St & Lafayette Ave        4428.02  40.672695 -73.954131
#
#      end_lat    end_lng member_casual
# 0  40.744876 -73.995299        member
# 1  40.744876 -73.995299        member
# 2  40.744876 -73.995299        member
# 3  40.687534 -73.972652        member
# 4  40.687534 -73.972652        member
#             ride_id  rideable_type               started_at  \
# 0  AE74944C8277552A   classic_bike  2026-08-13 11:15:19.068
# 1  9669210D7E9DE4F8   classic_bike  2026-08-04 15:38:37.778
# 2  2D800455B6943247  electric_bike  2026-08-01 12:00:03.691
# 3  E33007CF83E516E7  electric_bike  2026-08-12 14:48:23.583
# 4  33DB75C77C09D836  electric_bike  2026-08-11 13:45:03.829
#
#                   ended_at       start_station_name start_station_id  \
# 0  2026-08-13 11:17:56.989  Monroe St & Classon Ave          4336.01
# 1  2026-08-04 15:41:56.248  Monroe St & Classon Ave          4336.01
# 2  2026-08-01 12:02:34.810    Fulton St & Irving Pl          4263.12
# 3  2026-08-12 15:15:21.814       Front St & Pine St          4953.08
# 4  2026-08-11 13:52:01.181    E 46 St & Madison Ave          6551.16
#
#            end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0  Hancock St & Bedford Ave        4255.05  40.684568 -73.958811  40.682166
# 1  Hancock St & Bedford Ave        4255.05  40.684568 -73.958811  40.682166
# 2  Hancock St & Bedford Ave        4255.05  40.681860 -73.959432  40.682166
# 3           W 50 St & 9 Ave        6854.05  40.705310 -74.006130  40.763605
# 4           3 Ave & E 72 St        7028.04  40.755393 -73.977601  40.769943
#
#      end_lng member_casual
# 0 -73.953990        member
# 1 -73.953990        member
# 2 -73.953990        member
# 3 -73.989180        member
# 4 -73.960607        member
#             ride_id  rideable_type               started_at  \
# 0  8DE28BB8DE7E7B37   classic_bike  2026-08-08 13:09:07.617
# 1  26D1DFF0A7C10B8E   classic_bike  2026-08-06 08:18:45.376
# 2  D3C1E6BE59C03672   classic_bike  2026-08-04 08:13:55.475
# 3  896AB31C4062E923  electric_bike  2026-08-06 08:25:17.381
# 4  0D9343B067B9A8C1  electric_bike  2026-08-01 18:50:22.934
#
#                   ended_at           start_station_name start_station_id  \
# 0  2026-08-08 13:56:43.819        7 Ave S & Bleecker St          5805.07
# 1  2026-08-06 08:44:50.952         Ave C & McDonald Ave          2957.08
# 2  2026-08-04 08:41:50.638         Ave C & McDonald Ave          2957.08
# 3  2026-08-06 08:44:10.849             W 52 St & 11 Ave          6926.01
# 4  2026-08-01 18:54:29.064  Hancock St & Malcolm X Blvd          4342.04
#
#                   end_station_name end_station_id  start_lat  start_lng  \
# 0  Murray St & West St (NW Corner)        5329.09  40.732139 -74.003638
# 1  West Drive & Prospect Park West        3651.04  40.640344 -73.979152
# 2  West Drive & Prospect Park West        3651.04  40.640344 -73.979152
# 3  Murray St & West St (NW Corner)        5329.09  40.767272 -73.993929
# 4         Halsey St & Tompkins Ave        4319.07  40.684870 -73.929300
#
#      end_lat    end_lng member_casual
# 0  40.715438 -74.014077        casual
# 1  40.661063 -73.979453        member
# 2  40.661063 -73.979453        member
# 3  40.715438 -74.014077        member
# 4  40.682369 -73.944118        member
#                              station_id                     name short_name  \
# 0  0687075b-cf2d-4130-a859-fe841aafbd3f      Vernon Blvd & 41 Rd    6514.08
# 1  cb05443c-e68e-48f7-8d17-35353fa19d4d  W 34 St & Hudson Blvd E    6535.04
# 2  66db9c2e-0aca-11e7-82f6-3863bb44ef7c          Ave D & E 12 St    5575.08
# 3  66dc6a86-0aca-11e7-82f6-3863bb44ef7c     E 24 St & Park Ave S     6131.1
# 4                   1846085439406916338           41 Ave & 77 St    6290.06
#
#          lon        lat  region_id  capacity  \
# 0 -73.948568  40.755243       71.0        27
# 1 -74.000599  40.755167       71.0        57
# 2 -73.974225  40.725806       71.0        41
# 3 -73.986022  40.740964       71.0        79
# 4 -73.888200  40.745570       71.0        24
#
#                                          rental_uris         rental_methods  \
# 0  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  ['KEY', 'CREDITCARD']
# 1  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  ['KEY', 'CREDITCARD']
# 2  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  ['KEY', 'CREDITCARD']
# 3  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  ['KEY', 'CREDITCARD']
# 4  {'android': 'https://bkn.lft.to/lastmile_qr_sc...  ['KEY', 'CREDITCARD']
#
#    has_kiosk station_type                           external_id  \
# 0       True      classic  0687075b-cf2d-4130-a859-fe841aafbd3f
# 1       True      classic  cb05443c-e68e-48f7-8d17-35353fa19d4d
# 2       True      classic  66db9c2e-0aca-11e7-82f6-3863bb44ef7c
# 3       True      classic  66dc6a86-0aca-11e7-82f6-3863bb44ef7c
# 4       True      classic                   1846085439406916338
#
#    electric_bike_surcharge_waiver eightd_station_services  \
# 0                           False                      []
# 1                           False                      []
# 2                           False                      []
# 3                           False                      []
# 4                           False                      []
#
#    eightd_has_key_dispenser
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#                   time  temperature_2m  relative_humidity_2m  precipitation  \
# 0  2026-08-01 00:00:00            23.3                    84            0.0
# 1  2026-08-01 01:00:00            22.7                    85            0.0
# 2  2026-08-01 02:00:00            22.1                    89            0.0
# 3  2026-08-01 03:00:00            21.9                    91            0.0
# 4  2026-08-01 04:00:00            21.7                    93            0.0
#
#    wind_speed_10m
# 0             6.2
# 1             4.6
# 2             6.3
# 3             7.3
# 4             7.0

# %%
print(weather.head())
# Out:
#                   time  temperature_2m  relative_humidity_2m  precipitation  \
# 0  2026-08-01 00:00:00            23.3                    84            0.0
# 1  2026-08-01 01:00:00            22.7                    85            0.0
# 2  2026-08-01 02:00:00            22.1                    89            0.0
# 3  2026-08-01 03:00:00            21.9                    91            0.0
# 4  2026-08-01 04:00:00            21.7                    93            0.0
#
#    wind_speed_10m
# 0             6.2
# 1             4.6
# 2             6.3
# 3             7.3
# 4             7.0

# %%
weather
# Out:
#                     time  temperature_2m  relative_humidity_2m  precipitation  \
# 0    2026-08-01 00:00:00            23.3                    84            0.0
# 1    2026-08-01 01:00:00            22.7                    85            0.0
# 2    2026-08-01 02:00:00            22.1                    89            0.0
# 3    2026-08-01 03:00:00            21.9                    91            0.0
# 4    2026-08-01 04:00:00            21.7                    93            0.0
# ..                   ...             ...                   ...            ...
# 739  2026-08-31 19:00:00            22.8                    80            0.0
# 740  2026-08-31 20:00:00            23.1                    77            0.0
# 741  2026-08-31 21:00:00            22.7                    79            0.0
# 742  2026-08-31 22:00:00            22.5                    81            0.0
# 743  2026-08-31 23:00:00            22.2                    84            0.0
#
#      wind_speed_10m
# 0               6.2
# 1               4.6
# 2               6.3
# 3               7.3
# 4               7.0
# ..              ...
# 739             6.1
# 740             7.3
# 741             6.9
# 742             7.6
# 743             7.4
#
# [744 rows x 5 columns]
